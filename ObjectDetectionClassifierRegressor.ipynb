# %% [markdown]
# <a href="https://colab.research.google.com/github/epicure24/ObjectDetection-ComputerVision/blob/main/ObjectDetectionClassifierRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRAINING RESNET CLASSIFIER CUM REGRESSOR

# %%
#library imports
import os
import random
import math
import pandas as pd
import numpy as np

import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xml.etree.ElementTree as ET

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models

# %% [markdown]
# ## HELPER FUNCTIONS

# %%
# READ IMAGES IN COLORED FORMAT
def read_image(path):
    return cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)

# CREATE IMAGE LIST
def create_image_list(image_path):
    image_list = []
    # ITERATE THROUGH IMAGES FOLDER
    for image in os.listdir(image_path):
        # APPEND THE NAME OF IMAGES TO THE LIST
        image_list.append(image)
    return image_list

# CREATE MASK FOR BOUNDING BOX
def create_mask(bb, image):
    # EXTRACT THE IMAGE SHAPE
    rows,cols,*_ = image.shape
    # CREATE A MATRIX OF ZERO OF THE IMAGE SHAPE
    mask = np.zeros((rows, cols))
    # FILL THE MATRIX CONTAINING THE BOUNDING BOX WITH VALUE 1
    mask[bb[0]:bb[2], bb[1]:bb[3]] = 1.
    return mask

# CONVERT RESIZED MASK TO BOUNDING BOX
def convert_to_bb(mask):
    # EXTRACT THE SHAPE OF THE MASK OF BOUNDING BOX CREATED
    cols, rows = np.nonzero(mask)
    # RETURN ZERO COORDINATES IF NO MASK
    if len(cols)==0: 
        return np.zeros(4, dtype=np.float32)
    # EXTRACT THE BOUNDING BOX COORDINATES
    top_row = np.min(rows)
    left_col = np.min(cols)
    bottom_row = np.max(rows)
    right_col = np.max(cols)
    return np.array([left_col, top_row, right_col, bottom_row], dtype=np.float32)

# RESIZE THE IMAGES AND SAVE IT IN ANOTHER FOLDER
def image_resize(image_path, new_path, bb, size):
    # READ THE IMAGE FILE
    image = read_image(image_path)
    # RESIZE THE IMAGE
    image_resized = cv2.resize(image, (int(1.49*size), size))
    # CREATE MASK FROM THE BOUNDING BOX
    mask = create_mask(bb, image)
    # RESIZE THE MASK 
    mask_resized = cv2.resize(mask, (int(1.49*size), size))
    # WRITE THE NEW IMAGE INTO ANOTHER FOLDER
    cv2.imwrite(new_path, cv2.cvtColor(image_resized, cv2.COLOR_RGB2BGR))
    return new_path, convert_to_bb(mask_resized)

# PLOT THE BOUNDING BOX AROUND THE IMAGE
def plot_bb(path, bb):
    image = read_image(path)
    # CONVERT BOUNDING BOXES (BB) INTO FLOAT
    bb = np.array(bb, dtype=np.float32)
    # CREATE A RECTANGLE FROM THE BB
    rect_box = plt.Rectangle((bb[1], bb[0]), bb[3]-bb[1], bb[2]-bb[0], color='red',
                         fill=False, lw=3)
    # RENDER THE IMAGE
    plt.imshow(image)
    # APPLY THE BB TO THE CURRENT AXIS RENDERING IMAGE
    plt.gca().add_patch(rect_box)

# EXTRACT BOUNDING BOX FROM THE ANNOTATION FILE
def extract_bb(anno_path):
    # PARSE THE XML FILE TO EXTRACT BB COORDINATES AND CLASS_NAME
    root = ET.parse(anno_path).getroot()
    class_name = root.find("./object/name").text
    xmin = int(root.find("./object/bndbox/xmin").text)
    ymin = int(root.find("./object/bndbox/ymin").text)
    xmax = int(root.find("./object/bndbox/xmax").text)
    ymax = int(root.find("./object/bndbox/ymax").text)
    # RETURN BOUNDING BOX COORDINATES
    bb = [ymin, xmin, ymax, xmax]
    return bb, class_name

# GENERATE DATAFRAME
def generate_dataframe(image_list, anno_path, image_path, new_path, size):
    dataset = []
    for image in image_list:
        path = image_path + image
        a_path = anno_path + image.split('.')[0] + '.xml'
        # EXTRACT BB AND CLASS_NAME FROM ANNOTATION FILE
        bb, class_name = extract_bb(a_path)
        # FILENAME OF THE NEW RESIZED IMAGE
        n_path = new_path + image 
        # RESIZE THE IMAGE AND CORRESPONDING BOUNDING BOX 
        img_path, resized_bb = image_resize(path, n_path, bb, size)
        # APPEND EVERYTHING TO A DICTIONARY 
        data = dict()
        data['filename'] = img_path
        data['bb'] = resized_bb
        data['class_name'] = class_name
        # APPEND THE DICTIONARY TO THE LIST
        dataset.append(data)
    # APPEND THE LIST TO THE DATAFRAME 
    return pd.DataFrame(dataset)  

# NORMALIZE THE IMAGE PIXELS TO MATCH IMAGE_NET STATS
def normalize_image(image):
    # IMAGENET STATS 
    stats = np.array([[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]])
    return (image - stats[0])/stats[1] 

# EXTRACT IMAGE FROM THE IMAGE FILE
def extract_image(path):
    x = cv2.imread(str(path)).astype(np.float32)
    # SCALE THE IMAGE PIXELS
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)/255
    return x

# TRAIN THE MODEL 
def train_model(model, optimizer, train_dl, val_dl, epochs, C=1000):
    idx = 0
    # ITERATE THROUGH EPOCHS
    for i in range(epochs):
        model.train()
        total = 0
        sum_loss = 0
        # ITERATE THROUGH THE TENSORS
        for x, y_class, y_bb in train_dl:
            batch = y_class.shape[0]
            # IMAGE PIXELS TENSOR
            x = x.cuda().float()
            # CLASS TENSORS
            y_class = y_class.cuda()
            # BB TENSORS
            y_bb = y_bb.cuda().float()
            # LOAD THE TENSORS INTO MODEL AND PREDICT THE CLASS_NAMES AND BB
            out_class, out_bb = model(x)
            # CALCULATE LOSS BETWEEN THE ACTUAL & PREDICTED CLASS 
            loss_class = torch.nn.functional.cross_entropy(out_class, y_class, reduction="sum")
            # CALCULATE LOSS BETWEEN THE ACTUAL & PREDICTED BB COORDINATES
            loss_bb = torch.nn.functional.l1_loss(out_bb, y_bb, reduction="none").sum(1)
            # ADD THE 4 BB LOSSES INTO A SINGLE VALUE
            loss_bb = loss_bb.sum()
            # SCALE THE BB LOSS BY 1000 TO HAVE CLASS LOSS AND BB LOSS IN SAME RANGE
            loss = loss_class + loss_bb/C
            # SET GRADIENTS TO ZERO
            optimizer.zero_grad()
            # BACKPROPOGATE THE LOSS
            loss.backward()
            # UPDATE ALL PARAMETERS
            optimizer.step()
            idx += 1
            total += batch
            sum_loss += loss.item()
        # CALCULATE THE TOTAL TRAINING LOSS
        train_loss = sum_loss/total
        # CALCULATE THE VALIDATION LOSS AND ACCURACY
        val_loss, val_acc = calculate_validation_metrics(model, valid_dl, C)
        print("train_loss %.3f val_loss %.3f val_acc %.3f" % (train_loss, val_loss, val_acc))
    return sum_loss/total

# FOR CALCULATING VALIDATION LOSS AND ACCURACY
def calculate_validation_metrics(model, valid_dl, C=1000):
    model.eval()
    total = 0
    sum_loss = 0
    correct = 0 
    for x, y_class, y_bb in valid_dl:
        batch = y_class.shape[0]
        x = x.cuda().float()
        y_class = y_class.cuda()
        y_bb = y_bb.cuda().float()
        out_class, out_bb = model(x)
        loss_class = torch.nn.functional.cross_entropy(out_class, y_class, reduction="sum")
        loss_bb = torch.nn.functional.l1_loss(out_bb, y_bb, reduction="none").sum(1)
        loss_bb = loss_bb.sum()
        loss = loss_class + loss_bb/C
        _, pred = torch.max(out_class, 1)
        correct += pred.eq(y_class).sum().item()
        sum_loss += loss.item()
        total += batch
    return sum_loss/total, correct/total

# PREPARE THE DATASET TO PASS THROUGH MODEL
class Currency(Dataset):
    def __init__(self, paths, bb, y):
        self.paths = paths.values
        self.bb = bb.values
        self.y = y

    def __len__(self):
        return len(self.paths)
    
    def __getitem__(self, index):
        path = self.paths[index]
        y_class = self.y[index]
        y_bb = self.bb[index]
        x = extract_image(path)
        x = normalize_image(x)
        x = np.rollaxis(x, 2)
        return x, y_class, y_bb

# DEFINE MODEL ARCHITECTURE
class ResNetModel(torch.nn.Module):
    def __init__(self):
        super(ResNetModel, self).__init__()
        resnet = models.resnet34(pretrained=True)
        layers = list(resnet.children())[:8]
        self.features1 = torch.nn.Sequential(*layers[:6])
        self.features2 = torch.nn.Sequential(*layers[6:])
        self.classifier = torch.nn.Sequential(torch.nn.BatchNorm1d(512), torch.nn.Linear(512, 7))
        self.bb = torch.nn.Sequential(torch.nn.BatchNorm1d(512), torch.nn.Linear(512, 4))
        
    def forward(self, x):
        x = self.features1(x)
        x = self.features2(x)
        x = torch.nn.functional.relu(x)
        x = torch.nn.AdaptiveAvgPool2d((1,1))(x)
        x = x.view(x.shape[0], -1)
        y_class = torch.nn.functional.softmax(self.classifier(x), dim=1)
        return y_class, self.bb(x)

# %% [markdown]
# ## CREATE DATASET

# %%
# CREATE NEW FOLDER
# !mkdir resized_image 

image_path = '/content/drive/My Drive/Currency_Images/images/'
anno_path =  '/content/drive/My Drive/Currency_Images/annotations/'
new_path = '/content/resized_image/'

# CREATE IMAGE LIST
image_list = create_image_list(image_path)
# SHUFFLE THE LIST
np.random.shuffle(image_list)

# %%
# CREATE DATAFRAME
dataframe = generate_dataframe(image_list, anno_path, image_path, new_path, 300)

X = dataframe[['filename', 'bb']]
Y = dataframe['class_name']

# ENCODE THE CLASS NAMES
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)

# SPLIT INTO TRAIN AND VALIDATION SETS
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# CREATE DATASETS
train_ds = Currency(x_train['filename'],x_train['bb'] ,y_train)
valid_ds = Currency(x_val['filename'],x_val['bb'],y_val)

# PREPARE THE BATCH OF TRAINING AND VALIDATION TO LOAD
batch_size = 64
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_dl = DataLoader(valid_ds, batch_size=batch_size)

# %%
plot_bb(dataframe['filename'][4], dataframe['bb'][4])

# %%
dataframe.head()
# Out:
#                                   filename  ...   class_name
# 0       /content/resized_image/200_37.jpeg  ...   twoHundred
# 1       /content/resized_image/500_12.jpeg  ...  fiveHundred
# 2  /content/resized_image/20_1 (copy).jpeg  ...       twenty
# 3       /content/resized_image/200_15.jpeg  ...   twoHundred
# 4        /content/resized_image/20_13.jpeg  ...       twenty
#
# [5 rows x 3 columns]

# %%
# 0:50 1:500 2:100 3:10 4:20 5:200 6:2000
label_encoder.inverse_transform([0,1,2,3,4,5,6])
# Out:
# array(['fifty', 'fiveHundred', 'hundred', 'ten', 'twenty', 'twoHundred',
#        'twoThousand'], dtype=object)

# %% [markdown]
# ## TRAIN THE MODEL

# %%
# CALL MODEL AND SET PARAMETERS
res_model = ResNetModel().cuda()
parameters = filter(lambda param: param.requires_grad, res_model.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.001)

train_model(res_model, optimizer, train_dl, valid_dl, epochs=1000)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))
# train_loss 2.160 val_loss 2.539 val_acc 0.270
# train_loss 2.027 val_loss 2.433 val_acc 0.348
# train_loss 1.951 val_loss 2.179 val_acc 0.652
# train_loss 1.911 val_loss 2.254 val_acc 0.573
# train_loss 1.897 val_loss 2.048 val_acc 0.809
# train_loss 1.866 val_loss 2.137 val_acc 0.697
# train_loss 1.873 val_loss 1.928 val_acc 0.910
# train_loss 1.870 val_loss 1.976 val_acc 0.843
# train_loss 1.871 val_loss 1.968 val_acc 0.854
# train_loss 1.871 val_loss 2.002 val_acc 0.820
# train_loss 1.866 val_loss 1.986 val_acc 0.843
# train_loss 1.867 val_loss 1.896 val_acc 0.921
# train_loss 1.867 val_loss 2.071 val_acc 0.742
# train_loss 1.850 val_loss 2.020 val_acc 0.787
# train_loss 1.839 val_loss 1.944 val_acc 0.865
# train_loss 1.836 val_loss 1.890 val_acc 0.910
# train_loss 1.821 val_loss 1.875 val_acc 0.921
# train_loss 1.816 val_loss 1.854 val_acc 0.944
# train_loss 1.808 val_loss 1.847 val_acc 0.933
# train_loss 1.801 val_loss 1.828 val_acc 0.955
# train_loss 1.797 val_loss 1.903 val_acc 0.888
# train_loss 1.793 val_loss 1.851 val_acc 0.921
# train_loss 1.785 val_loss 1.851 val_acc 0.921
# train_loss 1.785 val_loss 1.832 val_acc 0.933
# train_loss 1.786 val_loss 1.811 val_acc 0.944
# train_loss 1.801 val_loss 1.930 val_acc 0.831
# train_loss 1.812 val_loss 1.834 val_acc 0.910
# train_loss 1.765 val_loss 2.074 val_acc 0.663
# train_loss 1.755 val_loss 1.908 val_acc 0.809
# train_loss 1.746 val_loss 1.831 val_acc 0.876
# train_loss 1.741 val_loss 1.860 val_acc 0.831
# train_loss 1.728 val_loss 1.856 val_acc 0.865
# train_loss 1.746 val_loss 1.786 val_acc 0.910
# train_loss 1.719 val_loss 1.767 val_acc 0.921
# train_loss 1.711 val_loss 1.845 val_acc 0.843
# train_loss 1.696 val_loss 1.873 val_acc 0.820
# train_loss 1.693 val_loss 1.770 val_acc 0.921
# train_loss 1.683 val_loss 1.811 val_acc 0.865
# train_loss 1.675 val_loss 1.844 val_acc 0.831
# train_loss 1.669 val_loss 1.787 val_acc 0.910
# train_loss 1.657 val_loss 1.762 val_acc 0.910
# train_loss 1.663 val_loss 1.698 val_acc 0.944
# train_loss 1.645 val_loss 1.721 val_acc 0.910
# train_loss 1.635 val_loss 1.716 val_acc 0.899
# train_loss 1.632 val_loss 1.694 val_acc 0.921
# train_loss 1.624 val_loss 1.692 val_acc 0.933
# train_loss 1.612 val_loss 1.690 val_acc 0.921
# train_loss 1.609 val_loss 1.676 val_acc 0.910
# train_loss 1.599 val_loss 1.676 val_acc 0.888
# train_loss 1.593 val_loss 1.659 val_acc 0.910
# train_loss 1.585 val_loss 1.647 val_acc 0.910
# train_loss 1.575 val_loss 1.626 val_acc 0.921
# train_loss 1.566 val_loss 1.626 val_acc 0.921
# train_loss 1.558 val_loss 1.629 val_acc 0.921
# train_loss 1.553 val_loss 1.632 val_acc 0.910
# train_loss 1.547 val_loss 1.645 val_acc 0.933
# train_loss 1.539 val_loss 1.603 val_acc 0.944
# train_loss 1.530 val_loss 1.611 val_acc 0.910
# train_loss 1.528 val_loss 1.605 val_acc 0.910
# train_loss 1.519 val_loss 1.607 val_acc 0.910
# train_loss 1.504 val_loss 1.580 val_acc 0.910
# train_loss 1.499 val_loss 1.567 val_acc 0.899
# train_loss 1.491 val_loss 1.616 val_acc 0.865
# train_loss 1.481 val_loss 1.612 val_acc 0.865
# train_loss 1.475 val_loss 1.604 val_acc 0.865
# train_loss 1.470 val_loss 1.539 val_acc 0.933
# train_loss 1.473 val_loss 1.549 val_acc 0.899
# train_loss 1.458 val_loss 1.571 val_acc 0.921
# train_loss 1.460 val_loss 1.550 val_acc 0.910
# train_loss 1.446 val_loss 1.542 val_acc 0.910
# train_loss 1.444 val_loss 1.538 val_acc 0.888
# train_loss 1.434 val_loss 1.545 val_acc 0.854
# train_loss 1.430 val_loss 1.505 val_acc 0.910
# train_loss 1.424 val_loss 1.510 val_acc 0.888
# train_loss 1.414 val_loss 1.522 val_acc 0.865
# train_loss 1.410 val_loss 1.495 val_acc 0.910
# train_loss 1.412 val_loss 1.502 val_acc 0.921
# train_loss 1.402 val_loss 1.483 val_acc 0.910
# train_loss 1.395 val_loss 1.486 val_acc 0.899
# train_loss 1.387 val_loss 1.477 val_acc 0.888
# train_loss 1.383 val_loss 1.507 val_acc 0.865
# train_loss 1.378 val_loss 1.635 val_acc 0.764
# train_loss 1.375 val_loss 1.463 val_acc 0.910
# train_loss 1.373 val_loss 1.495 val_acc 0.899
# train_loss 1.375 val_loss 1.446 val_acc 0.921
# train_loss 1.366 val_loss 1.428 val_acc 0.921
# train_loss 1.360 val_loss 1.427 val_acc 0.921
# train_loss 1.351 val_loss 1.430 val_acc 0.921
# train_loss 1.349 val_loss 1.425 val_acc 0.921
# train_loss 1.344 val_loss 1.421 val_acc 0.933
# train_loss 1.341 val_loss 1.445 val_acc 0.888
# train_loss 1.339 val_loss 1.429 val_acc 0.910
# train_loss 1.344 val_loss 1.433 val_acc 0.899
# train_loss 1.336 val_loss 1.400 val_acc 0.955
# train_loss 1.331 val_loss 1.429 val_acc 0.933
# train_loss 1.325 val_loss 1.405 val_acc 0.933
# train_loss 1.323 val_loss 1.420 val_acc 0.899
# train_loss 1.317 val_loss 1.486 val_acc 0.843
# train_loss 1.313 val_loss 1.411 val_acc 0.921
# train_loss 1.306 val_loss 1.404 val_acc 0.910
# train_loss 1.301 val_loss 1.391 val_acc 0.899
# train_loss 1.295 val_loss 1.384 val_acc 0.910
# train_loss 1.292 val_loss 1.376 val_acc 0.921
# train_loss 1.289 val_loss 1.374 val_acc 0.921
# train_loss 1.287 val_loss 1.342 val_acc 0.955
# train_loss 1.284 val_loss 1.346 val_acc 0.933
# train_loss 1.278 val_loss 1.345 val_acc 0.944
# train_loss 1.274 val_loss 1.348 val_acc 0.944
# train_loss 1.271 val_loss 1.334 val_acc 0.955
# train_loss 1.270 val_loss 1.328 val_acc 0.955
# train_loss 1.270 val_loss 1.328 val_acc 0.955
# train_loss 1.266 val_loss 1.338 val_acc 0.944
# train_loss 1.261 val_loss 1.338 val_acc 0.944
# train_loss 1.256 val_loss 1.375 val_acc 0.910
# train_loss 1.252 val_loss 1.376 val_acc 0.899
# train_loss 1.249 val_loss 1.369 val_acc 0.899
# train_loss 1.247 val_loss 1.365 val_acc 0.899
# train_loss 1.248 val_loss 1.351 val_acc 0.910
# train_loss 1.247 val_loss 1.344 val_acc 0.921
# train_loss 1.244 val_loss 1.336 val_acc 0.921
# train_loss 1.241 val_loss 1.324 val_acc 0.933
# train_loss 1.237 val_loss 1.336 val_acc 0.921
# train_loss 1.240 val_loss 1.324 val_acc 0.944
# train_loss 1.233 val_loss 1.338 val_acc 0.921
# train_loss 1.232 val_loss 1.339 val_acc 0.910
# train_loss 1.231 val_loss 1.337 val_acc 0.910
# train_loss 1.227 val_loss 1.329 val_acc 0.921
# train_loss 1.227 val_loss 1.338 val_acc 0.910
# train_loss 1.233 val_loss 1.326 val_acc 0.933
# train_loss 1.230 val_loss 1.346 val_acc 0.910
# train_loss 1.227 val_loss 1.343 val_acc 0.888
# train_loss 1.226 val_loss 1.338 val_acc 0.899
# train_loss 1.222 val_loss 1.346 val_acc 0.888
# train_loss 1.223 val_loss 1.329 val_acc 0.921
# train_loss 1.216 val_loss 1.312 val_acc 0.944
# train_loss 1.216 val_loss 1.312 val_acc 0.944
# train_loss 1.216 val_loss 1.311 val_acc 0.921
# train_loss 1.217 val_loss 1.321 val_acc 0.921
# train_loss 1.218 val_loss 1.323 val_acc 0.921
# train_loss 1.216 val_loss 1.306 val_acc 0.921
# train_loss 1.213 val_loss 1.301 val_acc 0.933
# train_loss 1.212 val_loss 1.306 val_acc 0.944
# train_loss 1.214 val_loss 1.303 val_acc 0.944
# train_loss 1.210 val_loss 1.302 val_acc 0.933
# train_loss 1.208 val_loss 1.297 val_acc 0.944
# train_loss 1.210 val_loss 1.295 val_acc 0.955
# train_loss 1.207 val_loss 1.295 val_acc 0.955
# train_loss 1.210 val_loss 1.301 val_acc 0.944
# train_loss 1.208 val_loss 1.299 val_acc 0.955
# train_loss 1.211 val_loss 1.302 val_acc 0.933
# train_loss 1.211 val_loss 1.304 val_acc 0.933
# train_loss 1.208 val_loss 1.308 val_acc 0.933
# train_loss 1.209 val_loss 1.311 val_acc 0.921
# train_loss 1.208 val_loss 1.299 val_acc 0.933
# train_loss 1.203 val_loss 1.295 val_acc 0.944
# train_loss 1.200 val_loss 1.300 val_acc 0.933
# train_loss 1.210 val_loss 1.306 val_acc 0.933
# train_loss 1.206 val_loss 1.310 val_acc 0.933
# train_loss 1.204 val_loss 1.304 val_acc 0.921
# train_loss 1.202 val_loss 1.307 val_acc 0.921
# train_loss 1.209 val_loss 1.301 val_acc 0.933
# train_loss 1.207 val_loss 1.296 val_acc 0.944
# train_loss 1.208 val_loss 1.293 val_acc 0.944
# train_loss 1.207 val_loss 1.294 val_acc 0.944
# train_loss 1.203 val_loss 1.297 val_acc 0.944
# train_loss 1.205 val_loss 1.291 val_acc 0.944
# train_loss 1.202 val_loss 1.292 val_acc 0.944
# train_loss 1.205 val_loss 1.294 val_acc 0.944
# train_loss 1.206 val_loss 1.302 val_acc 0.933
# train_loss 1.202 val_loss 1.301 val_acc 0.944
# train_loss 1.204 val_loss 1.298 val_acc 0.933
# train_loss 1.205 val_loss 1.297 val_acc 0.944
# train_loss 1.203 val_loss 1.300 val_acc 0.933
# train_loss 1.200 val_loss 1.291 val_acc 0.944
# train_loss 1.200 val_loss 1.292 val_acc 0.955
# train_loss 1.205 val_loss 1.297 val_acc 0.944
# train_loss 1.205 val_loss 1.295 val_acc 0.944
# train_loss 1.201 val_loss 1.293 val_acc 0.944
# train_loss 1.204 val_loss 1.294 val_acc 0.944
# train_loss 1.206 val_loss 1.293 val_acc 0.944
# train_loss 1.200 val_loss 1.293 val_acc 0.944
# train_loss 1.199 val_loss 1.296 val_acc 0.933
# train_loss 1.205 val_loss 1.287 val_acc 0.955
# train_loss 1.197 val_loss 1.289 val_acc 0.944
# train_loss 1.203 val_loss 1.291 val_acc 0.944
# train_loss 1.208 val_loss 1.290 val_acc 0.944
# train_loss 1.199 val_loss 1.284 val_acc 0.944
# train_loss 1.208 val_loss 1.290 val_acc 0.944
# train_loss 1.200 val_loss 1.328 val_acc 0.899
# train_loss 1.203 val_loss 1.331 val_acc 0.899
# train_loss 1.202 val_loss 1.309 val_acc 0.910
# train_loss 1.199 val_loss 1.291 val_acc 0.921
# train_loss 1.199 val_loss 1.291 val_acc 0.933
# train_loss 1.201 val_loss 1.294 val_acc 0.944
# train_loss 1.204 val_loss 1.291 val_acc 0.933
# train_loss 1.202 val_loss 1.307 val_acc 0.921
# train_loss 1.199 val_loss 1.305 val_acc 0.921
# train_loss 1.204 val_loss 1.307 val_acc 0.921
# train_loss 1.201 val_loss 1.309 val_acc 0.921
# train_loss 1.200 val_loss 1.304 val_acc 0.921
# train_loss 1.202 val_loss 1.304 val_acc 0.921
# train_loss 1.196 val_loss 1.306 val_acc 0.921
# train_loss 1.196 val_loss 1.303 val_acc 0.921
# train_loss 1.209 val_loss 1.304 val_acc 0.921
# train_loss 1.202 val_loss 1.302 val_acc 0.921
# train_loss 1.208 val_loss 1.304 val_acc 0.921
# train_loss 1.203 val_loss 1.301 val_acc 0.921
# train_loss 1.202 val_loss 1.307 val_acc 0.921
# train_loss 1.206 val_loss 1.298 val_acc 0.921
# train_loss 1.208 val_loss 1.300 val_acc 0.921
# train_loss 1.199 val_loss 1.304 val_acc 0.921
# train_loss 1.205 val_loss 1.305 val_acc 0.910
# train_loss 1.201 val_loss 1.301 val_acc 0.910
# train_loss 1.201 val_loss 1.303 val_acc 0.910
# train_loss 1.199 val_loss 1.293 val_acc 0.933
# train_loss 1.204 val_loss 1.293 val_acc 0.933
# train_loss 1.205 val_loss 1.291 val_acc 0.933
# train_loss 1.205 val_loss 1.287 val_acc 0.944
# train_loss 1.201 val_loss 1.285 val_acc 0.944
# train_loss 1.200 val_loss 1.288 val_acc 0.933
# train_loss 1.198 val_loss 1.296 val_acc 0.933
# train_loss 1.200 val_loss 1.297 val_acc 0.933
# train_loss 1.201 val_loss 1.299 val_acc 0.933
# train_loss 1.195 val_loss 1.301 val_acc 0.921
# train_loss 1.197 val_loss 1.286 val_acc 0.944
# train_loss 1.197 val_loss 1.279 val_acc 0.955
# train_loss 1.197 val_loss 1.276 val_acc 0.944
# train_loss 1.203 val_loss 1.276 val_acc 0.955
# train_loss 1.202 val_loss 1.276 val_acc 0.955
# train_loss 1.206 val_loss 1.280 val_acc 0.944
# train_loss 1.200 val_loss 1.286 val_acc 0.933
# train_loss 1.201 val_loss 1.285 val_acc 0.933
# train_loss 1.200 val_loss 1.287 val_acc 0.933
# train_loss 1.202 val_loss 1.289 val_acc 0.944
# train_loss 1.204 val_loss 1.283 val_acc 0.944
# train_loss 1.198 val_loss 1.289 val_acc 0.933
# train_loss 1.197 val_loss 1.296 val_acc 0.933
# train_loss 1.205 val_loss 1.291 val_acc 0.944
# train_loss 1.206 val_loss 1.290 val_acc 0.944
# train_loss 1.192 val_loss 1.285 val_acc 0.944
# train_loss 1.198 val_loss 1.287 val_acc 0.933
# train_loss 1.199 val_loss 1.285 val_acc 0.944
# train_loss 1.203 val_loss 1.279 val_acc 0.944
# train_loss 1.201 val_loss 1.278 val_acc 0.944
# train_loss 1.197 val_loss 1.275 val_acc 0.955
# train_loss 1.197 val_loss 1.273 val_acc 0.944
# train_loss 1.204 val_loss 1.279 val_acc 0.944
# train_loss 1.191 val_loss 1.281 val_acc 0.933
# train_loss 1.200 val_loss 1.274 val_acc 0.944
# train_loss 1.194 val_loss 1.278 val_acc 0.933
# train_loss 1.198 val_loss 1.282 val_acc 0.944
# train_loss 1.198 val_loss 1.282 val_acc 0.944
# train_loss 1.200 val_loss 1.282 val_acc 0.933
# train_loss 1.196 val_loss 1.287 val_acc 0.933
# train_loss 1.195 val_loss 1.290 val_acc 0.933
# train_loss 1.196 val_loss 1.284 val_acc 0.944
# train_loss 1.204 val_loss 1.284 val_acc 0.933
# train_loss 1.193 val_loss 1.285 val_acc 0.933
# train_loss 1.196 val_loss 1.283 val_acc 0.944
# train_loss 1.194 val_loss 1.282 val_acc 0.944
# train_loss 1.196 val_loss 1.283 val_acc 0.944
# train_loss 1.198 val_loss 1.287 val_acc 0.933
# train_loss 1.201 val_loss 1.288 val_acc 0.921
# train_loss 1.197 val_loss 1.291 val_acc 0.921
# train_loss 1.198 val_loss 1.289 val_acc 0.921
# train_loss 1.198 val_loss 1.288 val_acc 0.933
# train_loss 1.195 val_loss 1.288 val_acc 0.921
# train_loss 1.198 val_loss 1.286 val_acc 0.933
# train_loss 1.202 val_loss 1.285 val_acc 0.933
# train_loss 1.201 val_loss 1.284 val_acc 0.944
# train_loss 1.196 val_loss 1.284 val_acc 0.944
# train_loss 1.204 val_loss 1.289 val_acc 0.933
# train_loss 1.199 val_loss 1.288 val_acc 0.933
# train_loss 1.201 val_loss 1.289 val_acc 0.933
# train_loss 1.193 val_loss 1.284 val_acc 0.933
# train_loss 1.198 val_loss 1.280 val_acc 0.933
# train_loss 1.196 val_loss 1.281 val_acc 0.944
# train_loss 1.199 val_loss 1.329 val_acc 0.899
# train_loss 1.199 val_loss 1.289 val_acc 0.933
# train_loss 1.191 val_loss 1.295 val_acc 0.933
# train_loss 1.199 val_loss 1.295 val_acc 0.944
# train_loss 1.199 val_loss 1.369 val_acc 0.843
# train_loss 1.206 val_loss 1.307 val_acc 0.933
# train_loss 1.203 val_loss 1.307 val_acc 0.933
# train_loss 1.210 val_loss 1.315 val_acc 0.921
# train_loss 1.201 val_loss 1.366 val_acc 0.865
# train_loss 1.203 val_loss 1.357 val_acc 0.876
# train_loss 1.206 val_loss 1.310 val_acc 0.921
# train_loss 1.205 val_loss 1.320 val_acc 0.899
# train_loss 1.205 val_loss 1.302 val_acc 0.933
# train_loss 1.206 val_loss 1.311 val_acc 0.921
# train_loss 1.203 val_loss 1.325 val_acc 0.921
# train_loss 1.208 val_loss 1.329 val_acc 0.899
# train_loss 1.207 val_loss 1.318 val_acc 0.910
# train_loss 1.202 val_loss 1.330 val_acc 0.899
# train_loss 1.199 val_loss 1.297 val_acc 0.921
# train_loss 1.202 val_loss 1.291 val_acc 0.933
# train_loss 1.199 val_loss 1.288 val_acc 0.933
# train_loss 1.200 val_loss 1.285 val_acc 0.944
# train_loss 1.198 val_loss 1.291 val_acc 0.933
# train_loss 1.199 val_loss 1.288 val_acc 0.933
# train_loss 1.197 val_loss 1.284 val_acc 0.933
# train_loss 1.199 val_loss 1.273 val_acc 0.955
# train_loss 1.196 val_loss 1.270 val_acc 0.955
# train_loss 1.200 val_loss 1.266 val_acc 0.955
# train_loss 1.193 val_loss 1.266 val_acc 0.955
# train_loss 1.198 val_loss 1.270 val_acc 0.955
# train_loss 1.194 val_loss 1.271 val_acc 0.955
# train_loss 1.195 val_loss 1.269 val_acc 0.955
# train_loss 1.196 val_loss 1.266 val_acc 0.955
# train_loss 1.197 val_loss 1.264 val_acc 0.955
# train_loss 1.196 val_loss 1.266 val_acc 0.955
# train_loss 1.201 val_loss 1.268 val_acc 0.955
# train_loss 1.200 val_loss 1.265 val_acc 0.955
# train_loss 1.197 val_loss 1.266 val_acc 0.955
# train_loss 1.191 val_loss 1.266 val_acc 0.955
# train_loss 1.201 val_loss 1.273 val_acc 0.955
# train_loss 1.200 val_loss 1.271 val_acc 0.955
# train_loss 1.201 val_loss 1.268 val_acc 0.955
# train_loss 1.197 val_loss 1.267 val_acc 0.955
# train_loss 1.201 val_loss 1.266 val_acc 0.955
# train_loss 1.197 val_loss 1.264 val_acc 0.955
# train_loss 1.196 val_loss 1.267 val_acc 0.955
# train_loss 1.196 val_loss 1.270 val_acc 0.955
# train_loss 1.194 val_loss 1.277 val_acc 0.944
# train_loss 1.198 val_loss 1.276 val_acc 0.944
# train_loss 1.194 val_loss 1.276 val_acc 0.944
# train_loss 1.190 val_loss 1.273 val_acc 0.944
# train_loss 1.200 val_loss 1.267 val_acc 0.955
# train_loss 1.198 val_loss 1.272 val_acc 0.955
# train_loss 1.202 val_loss 1.275 val_acc 0.944
# train_loss 1.194 val_loss 1.274 val_acc 0.955
# train_loss 1.197 val_loss 1.273 val_acc 0.944
# train_loss 1.194 val_loss 1.273 val_acc 0.944
# train_loss 1.197 val_loss 1.271 val_acc 0.955
# train_loss 1.202 val_loss 1.278 val_acc 0.944
# train_loss 1.200 val_loss 1.272 val_acc 0.955
# train_loss 1.199 val_loss 1.271 val_acc 0.955
# train_loss 1.199 val_loss 1.276 val_acc 0.944
# train_loss 1.191 val_loss 1.273 val_acc 0.955
# train_loss 1.195 val_loss 1.274 val_acc 0.955
# train_loss 1.197 val_loss 1.278 val_acc 0.944
# train_loss 1.196 val_loss 1.279 val_acc 0.944
# train_loss 1.196 val_loss 1.279 val_acc 0.944
# train_loss 1.193 val_loss 1.275 val_acc 0.944
# train_loss 1.196 val_loss 1.270 val_acc 0.955
# train_loss 1.202 val_loss 1.269 val_acc 0.955
# train_loss 1.200 val_loss 1.269 val_acc 0.955
# train_loss 1.197 val_loss 1.269 val_acc 0.955
# train_loss 1.201 val_loss 1.271 val_acc 0.955
# train_loss 1.192 val_loss 1.278 val_acc 0.955
# train_loss 1.193 val_loss 1.268 val_acc 0.955
# train_loss 1.205 val_loss 1.260 val_acc 0.966
# train_loss 1.195 val_loss 1.260 val_acc 0.966
# train_loss 1.199 val_loss 1.267 val_acc 0.955
# train_loss 1.197 val_loss 1.272 val_acc 0.955
# train_loss 1.202 val_loss 1.272 val_acc 0.955
# train_loss 1.194 val_loss 1.268 val_acc 0.955
# train_loss 1.196 val_loss 1.270 val_acc 0.955
# train_loss 1.197 val_loss 1.273 val_acc 0.944
# train_loss 1.191 val_loss 1.269 val_acc 0.955
# train_loss 1.195 val_loss 1.271 val_acc 0.955
# train_loss 1.193 val_loss 1.274 val_acc 0.944
# train_loss 1.201 val_loss 1.274 val_acc 0.944
# train_loss 1.192 val_loss 1.273 val_acc 0.944
# train_loss 1.197 val_loss 1.273 val_acc 0.944
# train_loss 1.196 val_loss 1.275 val_acc 0.944
# train_loss 1.199 val_loss 1.273 val_acc 0.955
# train_loss 1.196 val_loss 1.273 val_acc 0.955
# train_loss 1.203 val_loss 1.278 val_acc 0.944
# train_loss 1.199 val_loss 1.278 val_acc 0.944
# train_loss 1.202 val_loss 1.276 val_acc 0.944
# train_loss 1.199 val_loss 1.273 val_acc 0.944
# train_loss 1.194 val_loss 1.275 val_acc 0.955
# train_loss 1.193 val_loss 1.278 val_acc 0.944
# train_loss 1.192 val_loss 1.273 val_acc 0.944
# train_loss 1.197 val_loss 1.272 val_acc 0.955
# train_loss 1.194 val_loss 1.273 val_acc 0.944
# train_loss 1.200 val_loss 1.275 val_acc 0.944
# train_loss 1.194 val_loss 1.282 val_acc 0.944
# train_loss 1.198 val_loss 1.290 val_acc 0.933
# train_loss 1.194 val_loss 1.302 val_acc 0.921
# train_loss 1.200 val_loss 1.270 val_acc 0.955
# train_loss 1.211 val_loss 1.293 val_acc 0.944
# train_loss 1.212 val_loss 1.367 val_acc 0.865
# train_loss 1.213 val_loss 1.347 val_acc 0.910
# train_loss 1.237 val_loss 1.365 val_acc 0.888
# train_loss 1.239 val_loss 1.364 val_acc 0.899
# train_loss 1.253 val_loss 1.814 val_acc 0.483
# train_loss 1.291 val_loss 1.837 val_acc 0.472
# train_loss 1.309 val_loss 2.025 val_acc 0.281
# train_loss 1.313 val_loss 1.749 val_acc 0.551
# train_loss 1.309 val_loss 1.684 val_acc 0.596
# train_loss 1.368 val_loss 1.621 val_acc 0.719
# train_loss 1.345 val_loss 1.516 val_acc 0.787
# train_loss 1.322 val_loss 1.585 val_acc 0.708
# train_loss 1.365 val_loss 1.809 val_acc 0.528
# train_loss 1.329 val_loss 1.830 val_acc 0.461
# train_loss 1.307 val_loss 1.530 val_acc 0.742
# train_loss 1.309 val_loss 1.631 val_acc 0.652
# train_loss 1.285 val_loss 1.453 val_acc 0.888
# train_loss 1.280 val_loss 1.462 val_acc 0.820
# train_loss 1.283 val_loss 1.373 val_acc 0.910
# train_loss 1.267 val_loss 1.360 val_acc 0.921
# train_loss 1.241 val_loss 1.345 val_acc 0.910
# train_loss 1.242 val_loss 1.345 val_acc 0.888
# train_loss 1.234 val_loss 1.312 val_acc 0.944
# train_loss 1.236 val_loss 1.315 val_acc 0.933
# train_loss 1.237 val_loss 1.326 val_acc 0.921
# train_loss 1.224 val_loss 1.317 val_acc 0.921
# train_loss 1.219 val_loss 1.313 val_acc 0.933
# train_loss 1.218 val_loss 1.308 val_acc 0.933
# train_loss 1.220 val_loss 1.302 val_acc 0.933
# train_loss 1.214 val_loss 1.300 val_acc 0.933
# train_loss 1.214 val_loss 1.297 val_acc 0.933
# train_loss 1.208 val_loss 1.299 val_acc 0.933
# train_loss 1.210 val_loss 1.295 val_acc 0.933
# train_loss 1.208 val_loss 1.296 val_acc 0.933
# train_loss 1.212 val_loss 1.297 val_acc 0.933
# train_loss 1.214 val_loss 1.285 val_acc 0.944
# train_loss 1.215 val_loss 1.282 val_acc 0.955
# train_loss 1.217 val_loss 1.280 val_acc 0.955
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8243658fe33a> in <module>()
#       4 optimizer = torch.optim.Adam(parameters, lr=0.001)
#       5
# ----> 6 train_model(res_model, optimizer, train_dl, valid_dl, epochs=1000)
#
# <ipython-input-2-f026538f1f37> in train_model(model, optimizer, train_dl, val_dl, epochs, C)
#     151         train_loss = sum_loss/total
#     152         # CALCULATE THE VALIDATION LOSS AND ACCURACY
# --> 153         val_loss, val_acc = calculate_validation_metrics(model, valid_dl, C)
#     154         print("train_loss %.3f val_loss %.3f val_acc %.3f" % (train_loss, val_loss, val_acc))
#     155     return sum_loss/total
#
# <ipython-input-2-f026538f1f37> in calculate_validation_metrics(model, valid_dl, C)
#     161     sum_loss = 0
#     162     correct = 0
# --> 163     for x, y_class, y_bb in valid_dl:
#     164         batch = y_class.shape[0]
#     165         x = x.cuda().float()
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-2-f026538f1f37> in __getitem__(self, index)
#     191         y_class = self.y[index]
#     192         y_bb = self.bb[index]
# --> 193         x = extract_image(path)
#     194         x = normalize_image(x)
#     195         x = np.rollaxis(x, 2)
#
# <ipython-input-2-f026538f1f37> in extract_image(path)
#     109     x = cv2.imread(str(path)).astype(np.float32)
#     110     # SCALE THE IMAGE PIXELS
# --> 111     x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)/255
#     112     return x
#     113
#
# KeyboardInterrupt:

# %% [markdown]
# ## EVALUATE THE MODEL

# %%
test_image = '10_1.jpeg'
test_ds = Currency(pd.DataFrame([{'path':'/content/resized_image/{}'.format(test_image)}])['path'],pd.DataFrame([{'bb':np.array([0,0,0,0])}])['bb'],pd.DataFrame([{'y':[0]}])['y'])
x, y_class, y_bb = test_ds[0]

xx = torch.FloatTensor(x[None,])
# 0 : fifty , 1: fiveHundred , 2: hundred
out_class, out_bb = res_model(xx.cuda())
out_class, out_bb
# Out:
# (tensor([[7.5453e-12, 5.4782e-12, 1.2368e-06, 1.0000e+00, 1.0998e-07, 1.0606e-08,
#           3.7439e-11]], device='cuda:0', grad_fn=<SoftmaxBackward>),
#  tensor([[ 51.5789,  17.7821, 260.2114, 404.9709]], device='cuda:0',
#         grad_fn=<AddmmBackward>))

# %%
currency_map = {0:'50Rs', 1:'500Rs', 2:'100Rs', 3:'10Rs', 4:'20Rs', 5:'200Rs', 6:'2000Rs'}

def identify_currency(image_path):

  im = read_image(image_path)
  test_ds = Currency(pd.DataFrame([{'path':'{}'.format(image_path)}])['path'],pd.DataFrame([{'bb':np.array([0,0,0,0])}])['bb'],pd.DataFrame([{'y':[0]}])['y'])
  x, y_class, y_bb = test_ds[0]
  xx = torch.FloatTensor(x[None,])
  out_class, out_bb = res_model(xx.cuda())
  index = out_class.cpu().data.numpy().argmax()
  confidence = out_class.cpu().data.numpy()[0][index]

  bb_hat = out_bb.detach().cpu().numpy()
  bb_hat = abs(bb_hat)
  plot_bb(image_path, bb_hat[0])
  output = '{}:{}'.format(currency_map[index], confidence)
  print(output)


img_path = '/content/resized_image/{}'.format(test_image)

identify_currency(img_path)
# Out:
# 10Rs:0.9999986886978149

# %%
torch.save(res_model, 'new_res_model.pth')
